# %% [markdown]
# !pip install pandas

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/cassielu/anaconda3/lib/python3.11/site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/cassielu/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/cassielu/anaconda3/lib/python3.11/site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/cassielu/anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/cassielu/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %% [markdown]
# Importing pandas

# %%
import pandas as pd

# %% [markdown]
# Read csv files

# %%
df = pd.read_csv('metadata_with_country_and_continent.csv')

df.sample(n=20)
# Out:
#       Unnamed: 0                                           WebTitle  \
# 1141        1141  Germany’s €9 train tickets scheme ‘saved 1.8m ...
# 1249        1249  ‘Britain called me a collaborator. Why?’ Ukrai...
# 460          460  Folly or art? Catalonian town to buy labyrinth...
# 515          515  Peru’s ousted president appears in court to fa...
# 467          467  ‘They want to kill us’: mayor Vitali Klitschko...
# 537          537  Swedish PM resigns after conceding election de...
# 440          440  Bilderberg reconvenes in person after two-year...
# 410          410  Onslaught of new abortion restrictions looms i...
# 114          114  Australia and the Netherlands launch legal act...
# 936          936  Mohammed bin Salman ‘will travel to London to ...
# 215          215  Being gay, I was deeply sceptical about marria...
# 979          979  ‘My heart is bleeding’: villagers flee as the ...
# 1002        1002  Xinjiang lockdown: Chinese censors drown out p...
# 1030        1030  How Gorbachev’s political legacy was destroyed...
# 1290        1290  Qatar’s gas output increase could cause catast...
# 65            65  What happened in the Russia-Ukraine war this w...
# 69            69  What happened in the Russia-Ukraine war this w...
# 366          366  ‘The biggest task is to combat indifference’: ...
# 302          302                                John Prior obituary
# 608          608  Grain deal clears one of many hurdles to get U...
#
#                                                  WebUrl  \
# 1141  https://www.theguardian.com/world/2022/aug/30/...
# 1249  https://www.theguardian.com/world/2022/feb/13/...
# 460   https://www.theguardian.com/world/2022/jul/18/...
# 515   https://www.theguardian.com/world/2022/dec/08/...
# 467   https://www.theguardian.com/world/2022/dec/07/...
# 537   https://www.theguardian.com/world/2022/sep/14/...
# 440   https://www.theguardian.com/world/2022/jun/04/...
# 410   https://www.theguardian.com/world/2022/dec/13/...
# 114   https://www.theguardian.com/world/2022/mar/14/...
# 936   https://www.theguardian.com/world/2022/sep/16/...
# 215   https://www.theguardian.com/world/2022/aug/28/...
# 979   https://www.theguardian.com/world/2022/oct/22/...
# 1002  https://www.theguardian.com/world/2022/sep/12/...
# 1030  https://www.theguardian.com/world/2022/aug/30/...
# 1290  https://www.theguardian.com/world/2022/dec/08/...
# 65    https://www.theguardian.com/world/2022/nov/19/...
# 69    https://www.theguardian.com/world/2022/dec/24/...
# 366   https://www.theguardian.com/world/2022/jan/26/...
# 302   https://www.theguardian.com/world/2022/jul/31/...
# 608   https://www.theguardian.com/world/2022/jul/22/...
#
#                         PubTime  \
# 1141  2022-08-30 15:28:59+00:00
# 1249  2022-02-13 08:30:18+00:00
# 460   2022-07-18 17:55:07+00:00
# 515   2022-12-08 19:33:24+00:00
# 467   2022-12-07 13:22:42+00:00
# 537   2022-09-14 22:58:55+00:00
# 440   2022-06-04 21:52:58+00:00
# 410   2022-12-13 10:00:46+00:00
# 114   2022-03-14 07:30:46+00:00
# 936   2022-09-15 23:08:28+00:00
# 215   2022-08-28 13:00:28+00:00
# 979   2022-10-22 14:00:10+00:00
# 1002  2022-09-12 04:55:26+00:00
# 1030  2022-08-30 22:25:02+00:00
# 1290  2022-12-08 06:00:48+00:00
# 65    2022-11-18 19:00:35+00:00
# 69    2022-12-23 18:00:10+00:00
# 366   2022-01-26 09:00:04+00:00
# 302   2022-07-31 16:37:56+00:00
# 608   2022-07-22 17:25:03+00:00
#
#                                                    Tags  TagCounts  \
# 1141  Germany, Rail transport, Travel and transport,...         15
# 1249  Ukraine, Foreign, Commonwealth and Development...         14
# 460   Catalonia, Architecture, Sculpture, Spain, Art...         16
# 515   Peru, Americas, World news, Article, News, Dan...         10
# 467   Kyiv, Vitali Klitschko, Ukraine, Russia, Europ...         14
# 537   Sweden, Europe, World news, Article, News, Dav...         10
# 440   Bilderberg, Nato, US news, World news, US poli...         11
# 410   Abortion, Roe v Wade, US news, Reproductive ri...          9
# 114   Malaysia Airlines flight MH17, Plane crashes, ...         16
# 936   Mohammed bin Salman, Queen Elizabeth II, Monar...         12
# 215   LGBTQ+ rights, Article, Drag, Comment, Marriag...         16
# 979   Ukraine, Vladimir Putin, Volodymyr Zelenskiy, ...         12
# 1002  China, Coronavirus, Xinjiang, Asia Pacific, In...         13
# 1030  Mikhail Gorbachev, Vladimir Putin, Russia, Nat...         16
# 1290  Qatar, Gas, Energy, Environment, Fossil fuels,...         12
# 65    Ukraine, Russia, Europe, World news, Poland, A...          8
# 69    Ukraine, Russia, Europe, World news, Belarus, ...         13
# 366   Nazism, Poland, Europe, World news, Antisemiti...         12
# 302   Catholicism, Other lives, Indonesia, Universit...         13
# 608   Ukraine, Food, Europe, Article, Analysis, Joan...         10
#
#                                                    Text  \
# 1141  Ukrainian troops are mounting a long-awaited c...
# 1249  Ukraine has allocated $592m (£437m) to guarant...
# 460   The alarm bells are ringing louder. Last week,...
# 515   Good morning. In years past, reports of cold w...
# 467   For decades, Cristina Fernández de Kirchner do...
# 537   A tentative agreement has been reached to aver...
# 440   People who contract Covid-19 are more likely t...
# 410   Benjamin Netanyahu’s Likud party has elected o...
# 114   A scheme giving offering Ukrainians home with ...
# 936   Prosecutors, police officers and journalists a...
# 215   Donald Scully gazes at his herd of 208 cows mu...
# 979   Xi Jinping has eliminated key rivals from Chin...
# 1002  The leader of the far-right Sweden Democrats, ...
# 1030  The familar face of Mikhail Gorbachev looks ou...
# 1290  Good morning. Everything is expensive. Food is...
# 65    Every week we wrap up the must-reads from our ...
# 69    Jamie Forsstroem is excited. Tomorrow they mak...
# 366   My father, Tony Moulam, who has died aged 94, ...
# 302   When she first tried for a seat in the Papua N...
# 608   In May 2021, Australia’s chief medical officer...
#
#                                                 Country  Continent
# 1141                                            Germany        NaN
# 1249                                            Ukraine        NaN
# 460                                               Spain        NaN
# 515                                                Peru        NaN
# 467                                     Ukraine, Russia        NaN
# 537                                              Sweden        NaN
# 440                                                 NaN        NaN
# 410                                                 NaN        NaN
# 114   Ukraine, Russia, Malaysia, Australia, Netherlands        NaN
# 936                                        Saudi Arabia        NaN
# 215                                                 NaN        NaN
# 979                                     Ukraine, Russia        NaN
# 1002                                              China        NaN
# 1030                                             Russia        NaN
# 1290                                              Qatar        NaN
# 65                              Ukraine, Russia, Poland        NaN
# 69                             Ukraine, Russia, Belarus        NaN
# 366                                              Poland        NaN
# 302                                           Indonesia        NaN
# 608                                             Ukraine        NaN

# %% [markdown]
# Top 5 white countries:
# Ukraine
# Russia
# Germany
# Poland
# Australia
#
# Top 5 non-white countries:
# China
# Iran
# Brazil
# India
# Taiwan
#
#
# Find all the rows of specific countries
#
# Put them in a dictionary

# %%
countries = ['Ukraine', 'Russia', 'Germany', 'Poland', 'Australia', 'China', 'Iran', 'Brazil', 'India', 'Taiwan']
country_dfs = {}

for country in countries:
    country_dfs[country] = df[df['Country'].str.contains(country, na=False)]

# %%
import os

for country, country_df in country_dfs.items():
    #
    country_folder = f'Country_corpus/{country}'
    os.makedirs(country_folder, exist_ok=True)

    # 遍历这些行
    for index, row in country_df.iterrows():
        # 设置文件名，例如使用行索引

        web_title = str(row['WebTitle']).replace('/', '-').replace('\\', '-')

        filename = os.path.join(country_folder, f"{web_title}.txt")

        # 将text列的内容写入文件
        with open(filename, 'w', encoding='utf-8') as file:
            file.write(str(row['Text']))
