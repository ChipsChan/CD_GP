# %% [markdown]
# !pip install pandas

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/cassielu/anaconda3/lib/python3.11/site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/cassielu/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/cassielu/anaconda3/lib/python3.11/site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/cassielu/anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/cassielu/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %% [markdown]
# Importing pandas

# %%
import pandas as pd

# %% [markdown]
# Read csv files

# %%
df = pd.read_csv('new_metadata_with_country_and_continent.CSV')

df.sample(n=20)
# Out:
#       Unnamed: 0                                           WebTitle  \
# 466          466  Hiroshima survivors plead for nuclear-free wor...
# 942          942  Russia-Ukraine war: Putin hints at ‘long’ conf...
# 794          794  Harassment of girls is still not being taken s...
# 712          712  ‘We were lucky to escape’: Kherson diarists te...
# 993          993  UN Afghanistan head meets Taliban over ban on ...
# 486          486  Lessons in patriotism used to justify Ukraine ...
# 106          106  Sri Lanka to hold state funeral for beloved sa...
# 1089        1089  Boris Johnson calls on west to ‘speak with one...
# 145          145   US Congress passes bill for $13.6bn in emerge...
# 338          338  Italian hairdressers face fines for shampooing...
# 804          804  Covid: one in 10 in England told to work despi...
# 428          428  Socialite who charmed Nato staff in Naples was...
# 103          103  Hungry badger may have uncovered Roman coins i...
# 868          868  Five things we learned about China’s ambitions...
# 1082        1082  Omicron variant does cause different symptoms ...
# 560          560  The west cannot dissociate itself from the con...
# 951          951  Impromptu takedown of painting in Netherlands ...
# 1057        1057  Kyiv piles pressure on Ankara to close straits...
# 1049        1049  ‘I had blood all over me’: Kramatorsk station ...
# 702          702  Nobel laureate Maria Ressa vows to fight Phili...
#
#                                                  WebUrl  \
# 466   https://www.theguardian.com/world/2022/oct/30/...
# 942   https://www.theguardian.com/world/live/2022/de...
# 794   https://www.theguardian.com/world/2022/oct/27/...
# 712   https://www.theguardian.com/world/2022/may/29/...
# 993   https://www.theguardian.com/world/2022/dec/26/...
# 486   https://www.theguardian.com/world/2022/apr/23/...
# 106   https://www.theguardian.com/world/2022/mar/08/...
# 1089  https://www.theguardian.com/world/2022/feb/18/...
# 145   https://www.theguardian.com/world/live/2022/ma...
# 338   https://www.theguardian.com/world/2022/jun/28/...
# 804   https://www.theguardian.com/world/2022/jul/09/...
# 428   https://www.theguardian.com/world/2022/aug/26/...
# 103   https://www.theguardian.com/world/2022/jan/09/...
# 868   https://www.theguardian.com/world/2022/may/26/...
# 1082  https://www.theguardian.com/world/2022/apr/07/...
# 560   https://www.theguardian.com/world/2022/aug/05/...
# 951   https://www.theguardian.com/world/2022/dec/27/...
# 1057  https://www.theguardian.com/world/2022/feb/26/...
# 1049  https://www.theguardian.com/world/2022/apr/13/...
# 702   https://www.theguardian.com/world/2022/jun/29/...
#
#                         PubTime  \
# 466   2022-10-30 04:00:16+00:00
# 942   2022-12-07 19:01:46+00:00
# 794   2022-10-27 17:33:18+00:00
# 712   2022-05-29 06:00:06+00:00
# 993   2022-12-26 16:40:42+00:00
# 486   2022-04-23 18:29:44+00:00
# 106   2022-03-08 06:36:19+00:00
# 1089  2022-02-18 22:30:17+00:00
# 145   2022-03-11 05:28:27+00:00
# 338   2022-06-28 11:09:21+00:00
# 804   2022-07-09 12:45:08+00:00
# 428   2022-08-26 13:28:30+00:00
# 103   2022-01-09 19:10:51+00:00
# 868   2022-05-26 00:09:00+00:00
# 1082  2022-04-07 22:01:04+00:00
# 560   2022-08-05 16:39:38+00:00
# 951   2022-12-27 05:30:14+00:00
# 1057  2022-02-26 16:52:25+00:00
# 1049  2022-04-13 05:00:42+00:00
# 702   2022-06-29 03:37:16+00:00
#
#                                                    Tags  TagCounts  \
# 466   Nuclear weapons, Japan, Second world war, Asia...         11
# 942   Ukraine war live, Ukraine, Russia, World news,...         17
# 794   Sexual harassment, Schools, Children, Mental h...         12
# 712   Ukraine, Russia, Europe, Article, Features, Mi...         10
# 993   Afghanistan, Taliban, Aid, South and central A...         15
# 486   Russia, Vladimir Putin, World news, Ukraine, S...         12
# 106   Sri Lanka, Animals, South and central Asia, Wo...         11
# 1089  Ukraine, Boris Johnson, Russia, Europe, Politi...         16
# 145   Ukraine, Ukraine war live, Russia, World news,...         32
# 338   Italy, Europe, World news, Article, News, Ange...         10
# 804   Coronavirus, Workers' rights, TUC, Infectious ...         18
# 428   Espionage, Investigative journalism, Russia, N...         15
# 103   Spain, Badgers, Archaeology, Animals, Wildlife...         14
# 868   The Pacific project, Pacific islands, World ne...         10
# 1082  Coronavirus, Medical research, Omicron variant...         13
# 560   Ukraine, Russia, Foreign policy, US foreign po...         10
# 951   Netherlands, Europe, World news, Universities,...         12
# 1057  Turkey, Ukraine, Russia, Recep Tayyip Erdoğan,...         13
# 1049  Ukraine, Europe, World news, Russia, Article, ...         12
# 702   Philippines, Media, Asia Pacific, Rodrigo Dute...         11
#
#                                                    Text  \
# 466   Toshiyuki Mimaki was playing in front of his f...
# 942   It’s 9pm in Kyiv. Here’s where we stand: Presi...
# 794   Sally Weale’s article (One in five girls in En...
# 712   After 48 days under Russian occupation, they w...
# 993   The acting head of the UN mission in Afghanist...
# 486   When Pavel Tkachev heard about the special les...
# 106   Sri Lanka is in mourning after the death of th...
# 1089  Boris Johnson will tell fellow western leaders...
# 145   Thanks for following our live coverage of the ...
# 338   The mayor of an Italian town has banned hairdr...
# 804   Nearly one in 10 workers with Covid symptoms a...
# 428   A team of investigators claim to have unmasked...
# 103   A trove of 209 Roman coins in a cave in northe...
# 868   Ten years ago, Pacific security thinkers would...
# 1082  People who have the Omicron Covid variant tend...
# 560   If Simon Jenkins believes the west is flirting...
# 951   A spur-of-the-moment decision by academic staf...
# 1057  Ukraine is increasing pressure on Turkey to ba...
# 1049  The evacuation train that was supposed to arri...
# 702   The Nobel prize-winner Maria Ressa has said sh...
#
#                          Country     Continent
# 466   Japan, Russia, North Korea  Asia, Europe
# 942     Ukraine, Ukraine, Russia        Europe
# 794                          NaN           NaN
# 712              Ukraine, Russia        Europe
# 993                  Afghanistan          Asia
# 486              Russia, Ukraine        Europe
# 106                    Sri Lanka          Asia
# 1089             Ukraine, Russia        Europe
# 145     Ukraine, Ukraine, Russia        Europe
# 338                        Italy        Europe
# 804                          NaN           NaN
# 428                Russia, Italy        Europe
# 103                        Spain        Europe
# 868                        China          Asia
# 1082                         NaN           NaN
# 560              Ukraine, Russia        Europe
# 951                  Netherlands        Europe
# 1057     Turkey, Ukraine, Russia  Asia, Europe
# 1049             Ukraine, Russia        Europe
# 702                  Philippines          Asia

# %% [markdown]
# Top 5 white countries:
# Ukraine Russia Germany New Zealand Australia
#
#
#
# Top 5 non-white countries:
# China Iran Brazil Taiwan Japan
#
#
# Finding all the rows of specific countries
#
# Putting them in a dictionary

# %%
countries = ['Ukraine', 'Russia', 'Germany', 'New Zealand', 'Australia', 'China', 'Iran', 'Brazil', 'Japan', 'Taiwan']
country_dfs = {}

for country in countries:
    country_dfs[country] = df[df['Country'].str.contains(country, na=False)]

# %% [markdown]
# Output the articles of each coutry in their own folder

# %%
import os


# Looping through each country and its corresponding DataFrame in the country_dfs dictionary
for country, country_df in country_dfs.items():
    #creating country folders
    country_folder = f'Country_corpus/{country}'
     # os.makedirs is used to create the directory; exist_ok=True means it won't throw an error if the folder already exists
    os.makedirs(country_folder, exist_ok=True)

    # Looping through each row in the country's DataFrame
    for index, row in country_df.iterrows():
        # Cleaning the web title to make it a valid filename. Replaces '/' and '\' with '-'
        web_title = str(row['WebTitle']).replace('/', '-').replace('\\', '-')
        # Creating the full file path by joining the country folder path and the cleaned web title
        filename = os.path.join(country_folder, f"{web_title}.txt")

        # Creating the full file path by joining the country folder path and the cleaned web title 
        with open(filename, 'w', encoding='utf-8') as file:
            file.write(str(row['Text']))
